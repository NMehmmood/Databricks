-- %%
USE CATALOG hive_metastore;
CREATE TABLE managed_table(length int, width int, height int );

INSERT INTO managed_table VALUES (3,4,5);

-- %%
DESCRIBE EXTENDED managed_table

-- %%
CREATE TABLE defauld_externalTable(length int,h INT, w INT)
LOCATION 'dbfs:/deno/defauld_externalT';
INSERT INTO defauld_externalTable (length, h, w) VALUES (1, 1, 1);

-- %%
DESCRIBE EXTENDED defauld_externaltable;

-- %%
%fs ls 'dbfs:/deno/defauld_externalT'

-- %%
%fs ls 'dbfs:/deno/defauld_externalT/_delta_log'

-- %%
DESCRIBE HISTORY defauld_externalT;

-- %%
insert into defauld_externalT values (1,1,1);
select * from defauld_externalT

-- %%
DESCRIBE HISTORY defauld_externalT;

-- %%
CREATE SCHEMA Demodb_1

-- %%
USE Demodb_1;
CREATE TABLE managed_table(length int, width int, height int );
INSERT INTO managed_table VALUES (3,4,5);
DESCRIBE EXTENDED managed_table;

-- %%
USE DATABASE demodb_1;
CREATE TABLE external_table1(length int, width int, height int )
LOCATION 'dbfs:/deno/external_table1 ';
INSERT INTO managed_table VALUES (3,5,5);

-- %%
DROP TABLE managed_table1

-- %%
select * FROM external_table1;

-- %%
DESCRIBE EXTENDED external_table1;

-- %%
DROP TABLE external_table1;
DROP TABLE managed_table;

-- %%
%fs ls 'dbfs:/deno/external_table1 ';

-- %%
CREATE SCHEMA db_2
LOCATION 'dbfs:/deno/db_2';
